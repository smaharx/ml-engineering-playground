# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/smaharx/ml-engineering-playground/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ## Unit of Analysis
#
# One row represents one content page and its search performance metrics for a specific reporting period. Each row contains historical information such as impressions, clicks, CTR, average position, search volume, and other content-related features that can help determine whether a page should be refreshed.
#
# ## Time Window
#
# For this assignment, I use a mid-panel month (March 2026) as recommended by the internship instructions. This avoids using the final outcome month and helps prevent information leakage during feature engineering and model development.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ## Features
#
# The features I plan to use include:
#
# - impressions_90d
# - ctr
# - avg_position
# - search_volume
# - content_age_days
#
# These variables are available before making a refresh decision and describe the historical performance of a page.
#
# ---
#
# ## Label / Target
#
# My target is to identify content pages that should be refreshed or ranked higher for optimization based on historical search performance.
#
# Since the starter dataset does not contain an explicit refresh label, this assignment uses a proxy target for framing purposes.
#
# ---
#
# ## Context Fields
#
# Context fields include:
#
# - content_type
# - position_tier
# - trend_direction
#
# These provide additional information about the page but are not direct prediction targets.
#
# ---
#
# ## Excluded Fields
#
# I deliberately exclude:
#
# - Client identifiers
# - URLs
# - Private search queries
# - Any future outcome information
#
# These are excluded to protect privacy and to avoid data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import os
import subprocess
import sys

REPO_NAME = "ml-engineering-playground"
REPO_URL = "https://github.com/smaharx/ml-engineering-playground.git"

if os.getcwd() == "/content":
    if not os.path.exists(REPO_NAME):
        print("Cloning repository...")
        subprocess.run(
            ["git", "clone", REPO_URL],
            check=True
        )

    os.chdir(REPO_NAME)

print(f"Working Directory: {os.getcwd()}")

assert os.path.exists(
    "data/raw/content_refresh_anonymized.csv"
), "Dataset not found. Check repository setup."

print("Repository setup complete.")
# Out:
# Working Directory: /content/ml-engineering-playground
# Repository setup complete.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ## Data Limitations
#
# This dataset provides historical search performance and supports decision-making, but it has important limitations.
#
# - It cannot prove cause-and-effect relationships.
# - It cannot predict Google's ranking algorithm.
# - The data represents historical observations rather than future certainty.
# - Some important factors, such as content quality, backlinks, or competitor activity, are not included.
# - Results should be interpreted as directional and decision-support evidence rather than absolute truth.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
