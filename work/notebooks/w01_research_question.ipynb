# %% [markdown]
# <a href="https://colab.research.google.com/github/smaharx/ml-engineering-playground/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/smaharx/ml-engineering-playground/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I'm choosing: Declining Pages Detection

Why? Pages losing search ranking is one of the biggest problems in SEO.
When a page declines, traffic drops fast, and revenue falls. By identifying
pages that WILL decline early (before it happens), the content team can
refresh them and prevent the loss. This is high-impact because it's about
being proactive instead of reactive.
# Out:
#   File "/tmp/ipykernel_868/1961528726.py", line 1
#     I'm choosing: Declining Pages Detection
#      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Decision: Which pages should the content team prioritize for refresh?

Who acts: The content/SEO team at FlyRank.

Action: Update stale content, improve titles/descriptions, refresh links.

Cost of being wrong:
- FALSE POSITIVE (flag a page as declining when it's not):
  Team wastes time refreshing a page that didn't need it.

- FALSE NEGATIVE (miss a page that IS declining):
  Revenue continues to drop. Traffic lost forever. Cost: $$$

We want to focus on precision — get it RIGHT for the top pages we flag.
# Out:
#   File "/tmp/ipykernel_868/27505712.py", line 8
#     - FALSE POSITIVE (flag a page as declining when it's not):
#                                                       ^
# SyntaxError: unterminated string literal (detected at line 8)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import numpy as np

# Load the data
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Total pages: {df.shape[0]}")
print(f"\nPages by trend:")
print(df["trend_direction"].value_counts())
print(f"\nPages that are DECLINING: {(df['trend_direction'] == 'down').sum()}")
print(f"Percentage declining: {round((df['trend_direction'] == 'down').mean() * 100, 1)}%")

print("\n\nDeclining pages lose traffic:")
down_pages = df[df["trend_direction"] == "down"]
up_pages = df[df["trend_direction"] == "up"]
print(f"Avg impressions (declining pages): {down_pages['impressions_90d'].mean():.0f}")
print(f"Avg impressions (growing pages):  {up_pages['impressions_90d'].mean():.0f}")
print(f"Difference: {down_pages['impressions_90d'].mean() - up_pages['impressions_90d'].mean():.0f} impressions")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_868/2648715812.py in <cell line: 0>()
#       3
#       4 # Load the data
# ----> 5 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       6
#       7 print(f"Total pages: {df.shape[0]}")
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
What this WILL be able to say:
- "These signals are correlated with pages that decline"
- "This model identifies 80% of pages that ACTUALLY declined (in hindsight)"
- "Pages with high days_since_update AND low impressions are directionally associated with decline"

What this will NEVER be:
- Proof that updating a page CAUSES it to grow back
- Prediction of Google's algorithm
- Proof of causation (only correlation)
- 100% accurate for all pages

Why the caveat?
We're predicting from observation, not from experiments. We see what happened,
but we don't know what would have happened if we'd taken different actions.
The model finds patterns, but those patterns might not be the *cause* of decline.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
